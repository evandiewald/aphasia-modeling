# %%
import tbdb

transcripts = tbdb.getTranscripts(
    {"corpusName": "aphasia", "corpora": [["aphasia", "English", "Protocol", "Fridriksson-2", "PWA"]]},
    True
)
transcripts
# Out:
# Running cells with 'aphasia-modeling (Python 3.12.11)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/evan/Documents/code/aphasia-modeling/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
transcripts
# Out:
# {'colHeadings': ['path',
#   'filename',
#   'languages',
#   'media',
#   'date',
#   'pid',
#   'designType',
#   'activityType',
#   'groupType'],
#  'data': []}
